# %%
#leer el csv
import pandas as pd
data = pd.read_csv('limpiezarealizada.csv', delimiter=",")
print(data.head())
#analisis del csv
data.describe()
#sacar una regresion  del csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import BayesianRidge
from sklearn.linear_model import ARDRegression
from sklearn.linear_model import PassiveAggressiveRegressor
from sklearn.linear_model import TheilSenRegressor
from sklearn.linear_model import RANSACRegressor
from sklearn.linear_model import HuberRegressor
# Out:
#    Unnamed: 0  bedrooms  bathrooms  sqft_living floors  waterfront  view  \
# 0           0         3          1         1180      1           0     0
# 1           1         3          2         2570      2           0     0
# 2           2         2          1          770      1           0     0
# 3           3         4          3         1960      1           0     0
# 4           4         3          2         1680      1           0     0
#
#    grade  sqft_above  sqft_basement        zipcode  sqft_living15   price
# 0      7        1180              0  310612.755725           1340  221900
# 1      7        2170            400  469928.767726           1690  538000
# 2      6         770              0  462488.869258           2720  180000
# 3      7        1050            910  551768.520913           1360  604000
# 4      8        1680              0  685675.843537           1800  510000

# %%
#regresion exponencial
x = data['bedrooms'].values.reshape(-1, 1)
y = data['price'].values.reshape(-1, 1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

regresion = make_pipeline(PolynomialFeatures(3), LinearRegression())

regresion.fit(x_train, y_train)

#graficar
plt.scatter(x_train, y_train, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Exponencial')
plt.xlabel('x')
plt.ylabel('y')

plt.show()

#predecir
print("prediccion")
y_pred = regresion.predict(x_test)
#precision de la prediccion
print('Precisión de la regresión exponencial: ', regresion.score(x_train, y_train))

#graficar

plt.scatter(x_test, y_test, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
#r2
print('R2: ', r2_score(y_test, y_pred))

# %%
#regresion exponencial
x = data['bathrooms'].values.reshape(-1, 1)
y = data['price'].values.reshape(-1, 1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

regresion = make_pipeline(PolynomialFeatures(3), LinearRegression())

regresion.fit(x_train, y_train)

#graficar
plt.scatter(x_train, y_train, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Exponencial')
plt.xlabel('x')
plt.ylabel('y')

plt.show()

#predecir
print("prediccion")
y_pred = regresion.predict(x_test)
#precision de la prediccion
print('Precisión de la regresión exponencial: ', regresion.score(x_train, y_train))

#graficar

plt.scatter(x_test, y_test, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
#r2
print('R2: ', r2_score(y_test, y_pred))

# %%
#regresion exponencial
x = data['sqft_living'].values.reshape(-1, 1)
y = data['price'].values.reshape(-1, 1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

regresion = make_pipeline(PolynomialFeatures(3), LinearRegression())

regresion.fit(x_train, y_train)

#graficar
plt.scatter(x_train, y_train, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Exponencial')
plt.xlabel('x')
plt.ylabel('y')

plt.show()

#predecir
print("prediccion")
y_pred = regresion.predict(x_test)
#precision de la prediccion
print('Precisión de la regresión exponencial: ', regresion.score(x_train, y_train))

#graficar

plt.scatter(x_test, y_test, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
#r2
print('R2: ', r2_score(y_test, y_pred))

# %%
#regresion exponencial
x = data['floors'].values.reshape(-1, 1)
y = data['price'].values.reshape(-1, 1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

regresion = make_pipeline(PolynomialFeatures(3), LinearRegression())

regresion.fit(x_train, y_train)

#graficar
plt.scatter(x_train, y_train, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Exponencial')
plt.xlabel('x')
plt.ylabel('y')

plt.show()

#predecir
print("prediccion")
y_pred = regresion.predict(x_test)
#precision de la prediccion
print('Precisión de la regresión exponencial: ', regresion.score(x_train, y_train))

#graficar

plt.scatter(x_test, y_test, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
#r2
print('R2: ', r2_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14244/2088902775.py in <module>
#       7 regresion = make_pipeline(PolynomialFeatures(3), LinearRegression())
#       8
# ----> 9 regresion.fit(x_train, y_train)
#      10
#      11 #graficar
#
# c:\Users\Familia\.Origin\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     339         """
#     340         fit_params_steps = self._check_fit_params(**fit_params)
# --> 341         Xt = self._fit(X, y, **fit_params_steps)
#     342         with _print_elapsed_time('Pipeline',
#     343                                  self._log_message(len(self.steps) - 1)):
#
# c:\Users\Familia\.Origin\lib\site-packages\sklearn\pipeline.py in _fit(self, X, y, **fit_params_steps)
#     301                 cloned_transformer = clone(transformer)
#     302             # Fit or load from cache the current transformer
# --> 303             X, fitted_transformer = fit_transform_one_cached(
#     304                 cloned_transformer, X, y, None,
#     305                 message_clsname='Pipeline',
#
# c:\Users\Familia\.Origin\lib\site-packages\joblib\memory.py in __call__(self, *args, **kwargs)
#     347
#     348     def __call__(self, *args, **kwargs):
# --> 349         return self.func(*args, **kwargs)
#     350
#     351     def call_and_shelve(self, *args, **kwargs):
#
# c:\Users\Familia\.Origin\lib\site-packages\sklearn\pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     752     with _print_elapsed_time(message_clsname, message):
#     753         if hasattr(transformer, 'fit_transform'):
# --> 754             res = transformer.fit_transform(X, y, **fit_params)
#     755         else:
#     756             res = transformer.fit(X, y, **fit_params).transform(X)
#
# c:\Users\Familia\.Origin\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
# --> 702             return self.fit(X, y, **fit_params).transform(X)
#     703
#     704
#
# c:\Users\Familia\.Origin\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
#    1702             Fitted transformer.
#    1703         """
# -> 1704         n_samples, n_features = self._validate_data(
#    1705             X, accept_sparse=True).shape
#    1706         combinations = self._combinations(n_features, self.degree,
#
# c:\Users\Familia\.Origin\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
#     422             out = X
#     423         else:
#
# c:\Users\Familia\.Origin\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\Users\Familia\.Origin\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     671                     array = array.astype(dtype, casting="unsafe", copy=False)
#     672                 else:
# --> 673                     array = np.asarray(array, order=order, dtype=dtype)
#     674             except ComplexWarning as complex_warning:
#     675                 raise ValueError("Complex data not supported\n"
#
# c:\Users\Familia\.Origin\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ValueError: could not convert string to float: '1,5'

# %%
#regresion exponencial
x = data['waterfront'].values.reshape(-1, 1)
y = data['price'].values.reshape(-1, 1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

regresion = make_pipeline(PolynomialFeatures(3), LinearRegression())

regresion.fit(x_train, y_train)

#graficar
plt.scatter(x_train, y_train, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Exponencial')
plt.xlabel('x')
plt.ylabel('y')

plt.show()

#predecir
print("prediccion")
y_pred = regresion.predict(x_test)
#precision de la prediccion
print('Precisión de la regresión exponencial: ', regresion.score(x_train, y_train))

#graficar

plt.scatter(x_test, y_test, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
#r2
print('R2: ', r2_score(y_test, y_pred))

# %%
#regresion exponencial
x = data['view'].values.reshape(-1, 1)
y = data['price'].values.reshape(-1, 1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

regresion = make_pipeline(PolynomialFeatures(3), LinearRegression())

regresion.fit(x_train, y_train)

#graficar
plt.scatter(x_train, y_train, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Exponencial')
plt.xlabel('x')
plt.ylabel('y')

plt.show()

#predecir
print("prediccion")
y_pred = regresion.predict(x_test)
#precision de la prediccion
print('Precisión de la regresión exponencial: ', regresion.score(x_train, y_train))

#graficar

plt.scatter(x_test, y_test, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
#r2
print('R2: ', r2_score(y_test, y_pred))

# %%
#regresion exponencial
x = data['grade'].values.reshape(-1, 1)
y = data['price'].values.reshape(-1, 1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

regresion = make_pipeline(PolynomialFeatures(3), LinearRegression())

regresion.fit(x_train, y_train)

#graficar
plt.scatter(x_train, y_train, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Exponencial')
plt.xlabel('x')
plt.ylabel('y')

plt.show()

#predecir
print("prediccion")
y_pred = regresion.predict(x_test)
#precision de la prediccion
print('Precisión de la regresión exponencial: ', regresion.score(x_train, y_train))

#graficar

plt.scatter(x_test, y_test, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
#r2
print('R2: ', r2_score(y_test, y_pred))

# %%
#regresion exponencial
x = data['sqft_above'].values.reshape(-1, 1)
y = data['price'].values.reshape(-1, 1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

regresion = make_pipeline(PolynomialFeatures(3), LinearRegression())

regresion.fit(x_train, y_train)

#graficar
plt.scatter(x_train, y_train, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Exponencial')
plt.xlabel('x')
plt.ylabel('y')

plt.show()

#predecir
print("prediccion")
y_pred = regresion.predict(x_test)
#precision de la prediccion
print('Precisión de la regresión exponencial: ', regresion.score(x_train, y_train))

#graficar

plt.scatter(x_test, y_test, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
#r2
print('R2: ', r2_score(y_test, y_pred))

# %%
#regresion exponencial
x = data['sqft_basement'].values.reshape(-1, 1)
y = data['price'].values.reshape(-1, 1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

regresion = make_pipeline(PolynomialFeatures(3), LinearRegression())

regresion.fit(x_train, y_train)

#graficar
plt.scatter(x_train, y_train, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Exponencial')
plt.xlabel('x')
plt.ylabel('y')

plt.show()

#predecir
print("prediccion")
y_pred = regresion.predict(x_test)
#precision de la prediccion
print('Precisión de la regresión exponencial: ', regresion.score(x_train, y_train))

#graficar

plt.scatter(x_test, y_test, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
#r2
print('R2: ', r2_score(y_test, y_pred))

# %%
#regresion exponencial
x = data['zipcode'].values.reshape(-1, 1)
y = data['price'].values.reshape(-1, 1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

regresion = make_pipeline(PolynomialFeatures(3), LinearRegression())

regresion.fit(x_train, y_train)

#graficar
plt.scatter(x_train, y_train, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Exponencial')
plt.xlabel('x')
plt.ylabel('y')

plt.show()

#predecir
print("prediccion")
y_pred = regresion.predict(x_test)
#precision de la prediccion
print('Precisión de la regresión exponencial: ', regresion.score(x_train, y_train))

#graficar

plt.scatter(x_test, y_test, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
#r2
print('R2: ', r2_score(y_test, y_pred))

# %%
#regresion exponencial
x = data['sqft_living15'].values.reshape(-1, 1)
y = data['price'].values.reshape(-1, 1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

regresion = make_pipeline(PolynomialFeatures(3), LinearRegression())

regresion.fit(x_train, y_train)

#graficar
plt.scatter(x_train, y_train, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Exponencial')
plt.xlabel('x')
plt.ylabel('y')

plt.show()

#predecir
print("prediccion")
y_pred = regresion.predict(x_test)
#precision de la prediccion
print('Precisión de la regresión exponencial: ', regresion.score(x_train, y_train))

#graficar

plt.scatter(x_test, y_test, color='red')
plt.plot(x_train, regresion.predict(x_train), color='blue')
plt.title('Regresion Lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
#r2
print('R2: ', r2_score(y_test, y_pred))
